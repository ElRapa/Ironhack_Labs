# %% [markdown]
# # Lab Customer Analysis Case Study
#
# ## import libraries

# %%
import numpy as np
import pandas as pd

# %%
# load data and store in variable
file1 = pd.read_csv("Data/file1.csv")
file2 = pd.read_csv("Data/file2.csv")
file3 = pd.read_csv("Data/file3.csv")

# %%
# create functions to rename and sort columns
# make columns lower case
def make_columns_lower_case(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# replace space " " with underscore "_"
def replace_space(df):
    df.columns=[i.replace(" ","_") for i in df.columns]
    return df

# lower and replace space
def columns_lower_no_space(df):
    """ 
    Info: Columns of DataFrame will be manipulated: 
            1. All letters will be lowered.
            2. Spaces " " will be replaced with underscores "_"
    """
    make_columns_lower_case(df)
    replace_space(df)
    return df

# %%
# modify column: lower letters and replace space
file1 = columns_lower_no_space(file1)
file2 = columns_lower_no_space(file2)
file3 = columns_lower_no_space(file3)

# %%
file1_strip = file1.customer_lifetime_value.str.rstrip('!?% \n\t').astype("float64") /100
file1_strip.describe()
# Out:
# count     1068.000000
# mean      7936.902593
# std       6434.784103
# min       2004.350700
# 25%       4034.079950
# 50%       5881.742350
# 75%       8962.871975
# max      58166.553500
# Name: customer_lifetime_value, dtype: float64

# %%
file2_strip = file2.customer_lifetime_value.str.rstrip('!?% \n\t').astype("float64") /100
file2_strip.describe()
# Out:
# count      992.000000
# mean      7651.493931
# std       6214.652859
# min       2004.350700
# 25%       3924.119200
# 50%       5627.053750
# 75%       8690.526075
# max      49221.430700
# Name: customer_lifetime_value, dtype: float64

# %%
file3.customer_lifetime_value.describe()
# Out:
# count     7070.000000
# mean      8028.803803
# std       6942.419253
# min       1898.007675
# 25%       3981.073024
# 50%       5782.095838
# 75%       8989.995803
# max      83325.381190
# Name: customer_lifetime_value, dtype: float64

# %%
# compare the columns
pd.DataFrame([file1.columns,file2.columns,file3.columns])
# Out:
#          0      1                        2          3   \
# 0  customer     st                   gender  education
# 1  customer     st                   gender  education
# 2  customer  state  customer_lifetime_value  education
#
#                         4       5                     6   \
# 0  customer_lifetime_value  income  monthly_premium_auto
# 1  customer_lifetime_value  income  monthly_premium_auto
# 2                   gender  income  monthly_premium_auto
#
#                           7                   8                   9   \
# 0  number_of_open_complaints         policy_type       vehicle_class
# 1  number_of_open_complaints  total_claim_amount         policy_type
# 2  number_of_open_complaints         policy_type  total_claim_amount
#
#                    10
# 0  total_claim_amount
# 1       vehicle_class
# 2       vehicle_class

# %%
#Rename/Match column-names
file1.rename(columns={"st" : "state"}, inplace=True)
file2.rename(columns={"st" : "state"}, inplace=True)

# %%
# check column names again
pd.DataFrame([file1.columns,file2.columns,file3.columns])
# Out:
#          0      1                        2          3   \
# 0  customer  state                   gender  education
# 1  customer  state                   gender  education
# 2  customer  state  customer_lifetime_value  education
#
#                         4       5                     6   \
# 0  customer_lifetime_value  income  monthly_premium_auto
# 1  customer_lifetime_value  income  monthly_premium_auto
# 2                   gender  income  monthly_premium_auto
#
#                           7                   8                   9   \
# 0  number_of_open_complaints         policy_type       vehicle_class
# 1  number_of_open_complaints  total_claim_amount         policy_type
# 2  number_of_open_complaints         policy_type  total_claim_amount
#
#                    10
# 0  total_claim_amount
# 1       vehicle_class
# 2       vehicle_class

# %%
# Concat files

df = pd.concat([file1,file2,file3],ignore_index = True)
df
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       number_of_open_complaints     policy_type  vehicle_class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        total_claim_amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly_premium_auto       9137 non-null   float64
#  7   number_of_open_complaints  9137 non-null   object
#  8   policy_type                9137 non-null   object
#  9   vehicle_class              9137 non-null   object
#  10  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.0+ MB

# %%
round(df.isna().sum()/len(df),4)*100
# Out:
# customer                     24.32
# state                        24.32
# gender                       25.34
# education                    24.32
# customer_lifetime_value      24.38
# income                       24.32
# monthly_premium_auto         24.32
# number_of_open_complaints    24.32
# policy_type                  24.32
# vehicle_class                24.32
# total_claim_amount           24.32
# dtype: float64

# %% [markdown]
# # Start cleaning Data
# ## Drop empty lines (all nan)

# %%
df = df.dropna(how="all")
df = df.reset_index().drop(columns={"index"})
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9132  LA72316  California      M              Bachelor
# 9133  PK87824  California      F               College
# 9134  TD14365  California      M              Bachelor
# 9135  UP19263  California      M               College
# 9136  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 9132             23405.98798  71941.0                  73.0
# 9133             3096.511217  21604.0                  79.0
# 9134             8163.890428      0.0                  85.0
# 9135             7524.442436  21941.0                  96.0
# 9136             2611.836866      0.0                  77.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 9132                         0   Personal Auto  Four-Door Car
# 9133                         0  Corporate Auto  Four-Door Car
# 9134                         3  Corporate Auto  Four-Door Car
# 9135                         0   Personal Auto  Four-Door Car
# 9136                         0  Corporate Auto   Two-Door Car
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 9132          198.234764
# 9133          379.200000
# 9134          790.784983
# 9135          691.200000
# 9136          369.600000
#
# [9137 rows x 11 columns]

# %% [markdown]
# ## Clean data of individual columns
# ### Clean custome lifetime value:
#     - create function
#         - identify "%".
#         - strip %
#         - make float/numeric
#         - divide by 100
#     - imply function on column customer_lifetime_value

# %%
# create function to identify and strip %. turn to float/numeric and divide by 100
def clean_percentage(number):
    if type(number) in [float,int]:
        return number
    else:
        if "%" in number:
            return pd.to_numeric(number.rstrip("%"))/100
        else: 
            try:
                return pd.to_numeric(number)
            except ValueError:
                return number

# test function
# list(map(clean_percentage,[100,200.0,"300","400%","sdf"]))

# %%
## apply clean_percentage on customer_lifetime_value

df["customer_lifetime_value"] = list(map(clean_percentage, df["customer_lifetime_value"]))

# %%
df.customer.describe()
# Out:
# count        9137
# unique       9056
# top       FM14335
# freq            2
# Name: customer, dtype: object

# %%
def compare_duplicates( df = df, column = None  , amount = 10):
    ''' 
    compare_duplicates( DataFrame = df, column = none, amount = 10)
    
    column:     column to check for duplicated, if None > check all columns
    amount:     show first first amount of rows
    '''

    try:
        return df.loc[df.duplicated(subset=column, keep=False)].sort_values(by=column).head(amount)
    except KeyError:
        print("No duplicates")

# %%
compare_duplicates(df, "customer", 60)
# Out:
#      customer       state gender             education  \
# 2888  AC40767  Washington      M              Bachelor
# 741   AC40767  Washington      M             Bachelors
# 1706  AI49712  Washington      F  High School or Below
# 3592  AI49712  Washington      F  High School or Below
# 416   AX86150  Washington      M  High School or Below
# 2086  AX86150  Washington      M  High School or Below
# 2442  AY18433  Washington      F  High School or Below
# 884   AY18433  Washington      F  High School or Below
# 1373  BE61743  Washington      M              Bachelor
# 3400  BE61743  Washington      M              Bachelor
# 594   BH35482  Washington      M                Doctor
# 2663  BH35482  Washington      M                Doctor
# 2158  BH86846  Washington      M  High School or Below
# 440   BH86846  Washington      M  High School or Below
# 2675  BJ22117  Washington      M                Master
# 1187  BJ22117  Washington      M                Master
# 178   BN90616  Washington      F              Bachelor
# 3548  BN90616  Washington      F              Bachelor
# 3377  BW80872  Washington      M  High School or Below
# 546   BW80872  Washington      M  High School or Below
# 3090  BW94308  Washington      F  High School or Below
# 2046  BW94308  Washington      F  High School or Below
# 354   CI38330  Washington      M              Bachelor
# 3533  CI38330  Washington      M              Bachelor
# 3066  CR33417  Washington      F                Master
# 1091  CR33417  Washington      F                Master
# 1072  CW49887  California      F                Master
# 1069  CW49887  California      F                Master
# 2973  DP92488  Washington      F                Doctor
# 1444  DP92488  Washington      F                Doctor
# 661   EE99484  Washington      F  High School or Below
# 2244  EE99484  Washington      F  High School or Below
# 1499  EM85557  Washington      F               College
# 2772  EM85557  Washington      F               College
# 3421  FM14335  Washington      F               College
# 120   FM14335  Washington      F               College
# 933   FX36546  Washington      M                Master
# 3803  FX36546  Washington      M                Master
# 4     GA49547  Washington      M  High School or Below
# 3937  GA49547  Washington      M  High School or Below
# 1323  GK48045  Washington      F               College
# 2496  GK48045  Washington      F               College
# 1471  GK67747  Washington      M               College
# 3113  GK67747  Washington      M               College
# 3736  GP39118  Washington      M  High School or Below
# 111   GP39118  Washington      M  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1071  GS98873     Arizona      F              Bachelor
# 176   GX84338  Washington      F                Doctor
# 3253  GX84338  Washington      F                Doctor
# 1947  HL33607  Washington      M               College
# 2917  HL33607  Washington      M               College
# 2741  HQ70429  Washington      F               College
# 731   HQ70429  Washington      F               College
# 3042  HS14476  Washington      M               College
# 27    HS14476  Washington      M               College
# 2395  HX74855  Washington      M  High School or Below
# 436   HX74855  Washington      M  High School or Below
# 957   HX77930  Washington      F               College
# 3203  HX77930  Washington      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 2888              2497.808174  68041.0                  64.0
# 741               2497.808200  68041.0                6464.0
# 1706              2593.897900      0.0                  72.0
# 3592              2593.897887      0.0                  72.0
# 416               2656.713100  62777.0                  67.0
# 2086              2656.713092  62777.0                  67.0
# 2442             27382.818930  45473.0                  76.0
# 884              27382.818900  45473.0                  76.0
# 1373              4109.793600  86657.0                 103.0
# 3400              4109.793608  86657.0                 103.0
# 594               4930.949300  70412.0                  61.0
# 2663              4930.949334  70412.0                  61.0
# 2158             20708.258810  92079.0                  65.0
# 440              20708.258800  92079.0                  65.0
# 2675              5133.414764  53390.0                  64.0
# 1187              5133.414800  53390.0                6464.0
# 178               8590.335000  63110.0                  72.0
# 3548              8590.334983  63110.0                  72.0
# 3377              4434.411172  34549.0                 111.0
# 546               4434.411200  34549.0                 111.0
# 3090             20096.893370  92766.0                  71.0
# 2046             20096.893400  92766.0                  71.0
# 354               2549.786100  72217.0                6464.0
# 3533              2549.786069  72217.0                  64.0
# 3066              4762.156975  36529.0                 118.0
# 1091              4762.157000  36529.0                 118.0
# 1072              4626.801100  79487.0                 114.0
# 1069              4626.801100  79487.0                 114.0
# 2973              2727.520769  74592.0                  67.0
# 1444              2727.520800  74592.0                  67.0
# 661               2514.592000  43860.0                  65.0
# 2244              2514.591960  43860.0                  65.0
# 1499              8021.067100  54292.0                  67.0
# 2772              8021.067105  54292.0                  67.0
# 3421             10484.915350  61108.0                  89.0
# 120              10484.915400  61108.0                  89.0
# 933               3679.142100  60804.0                  92.0
# 3803              3679.142115  60804.0                  92.0
# 4                 5363.076500  36357.0                  68.0
# 3937              5363.076547  36357.0                  68.0
# 1323              8214.602400  73245.0                  68.0
# 2496              8214.602384  73245.0                  68.0
# 1471              4386.277600  10621.0                  67.0
# 3113              4386.277558  10621.0                  67.0
# 3736              4996.552721  71600.0                  63.0
# 111               4996.552700  71600.0                  63.0
# 1068              3239.124700  16061.0                  88.0
# 1071              3239.124700  16061.0                  88.0
# 176               3824.431300  62530.0                  95.0
# 3253              3824.431298  62530.0                  95.0
# 1947              8717.049800  83846.0                  74.0
# 2917              8717.049833  83846.0                  74.0
# 2741             16045.109520      0.0                  65.0
# 731              16045.109500      0.0                  65.0
# 3042              9162.063169  29723.0                  80.0
# 27                9162.063200  29723.0                  80.0
# 2395              2471.528431  95697.0                  61.0
# 436               2471.528400  95697.0                  61.0
# 957               3136.432100  49532.0                  79.0
# 3203              3136.432103  49532.0                  79.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 2888                         0   Personal Auto   Two-Door Car
# 741                     1/0/00   Personal Auto   Two-Door Car
# 1706                    1/0/00   Personal Auto  Four-Door Car
# 3592                         0   Personal Auto  Four-Door Car
# 416                     1/0/00   Personal Auto   Two-Door Car
# 2086                         0   Personal Auto   Two-Door Car
# 2442                         0    Special Auto   Two-Door Car
# 884                     1/0/00    Special Auto   Two-Door Car
# 1373                    1/0/00   Personal Auto     Sports Car
# 3400                         0   Personal Auto     Sports Car
# 594                     1/0/00  Corporate Auto   Two-Door Car
# 2663                         0  Corporate Auto   Two-Door Car
# 2158                         1  Corporate Auto  Four-Door Car
# 440                     1/1/00  Corporate Auto  Four-Door Car
# 2675                         0   Personal Auto  Four-Door Car
# 1187                    1/0/00   Personal Auto  Four-Door Car
# 178                     1/0/00   Personal Auto  Four-Door Car
# 3548                         0   Personal Auto  Four-Door Car
# 3377                         0   Personal Auto  Four-Door Car
# 546                     1/0/00   Personal Auto  Four-Door Car
# 3090                         0   Personal Auto   Two-Door Car
# 2046                    1/0/00   Personal Auto   Two-Door Car
# 354                     1/0/00   Personal Auto  Four-Door Car
# 3533                         0   Personal Auto  Four-Door Car
# 3066                         0   Personal Auto            SUV
# 1091                    1/0/00   Personal Auto            SUV
# 1072                    1/0/00    Special Auto            SUV
# 1069                    1/0/00    Special Auto            SUV
# 2973                         0   Personal Auto   Two-Door Car
# 1444                    1/0/00   Personal Auto   Two-Door Car
# 661                     1/0/00  Corporate Auto  Four-Door Car
# 2244                         0  Corporate Auto  Four-Door Car
# 1499                    1/0/00   Personal Auto  Four-Door Car
# 2772                         0   Personal Auto  Four-Door Car
# 3421                         0   Personal Auto  Four-Door Car
# 120                     1/0/00   Personal Auto  Four-Door Car
# 933                     1/0/00   Personal Auto  Four-Door Car
# 3803                         0   Personal Auto  Four-Door Car
# 4                       1/0/00   Personal Auto  Four-Door Car
# 3937                         0   Personal Auto  Four-Door Car
# 1323                    1/0/00   Personal Auto  Four-Door Car
# 2496                         0   Personal Auto  Four-Door Car
# 1471                    1/0/00    Special Auto  Four-Door Car
# 3113                         0    Special Auto  Four-Door Car
# 3736                         0   Personal Auto   Two-Door Car
# 111                     1/0/00   Personal Auto   Two-Door Car
# 1068                    1/0/00   Personal Auto  Four-Door Car
# 1071                    1/0/00   Personal Auto  Four-Door Car
# 176                     1/0/00   Personal Auto  Four-Door Car
# 3253                         0   Personal Auto  Four-Door Car
# 1947                    1/3/00   Personal Auto  Four-Door Car
# 2917                         3   Personal Auto  Four-Door Car
# 2741                         0   Personal Auto   Two-Door Car
# 731                     1/0/00   Personal Auto   Two-Door Car
# 3042                         0   Personal Auto  Four-Door Car
# 27                      1/0/00   Personal Auto  Four-Door Car
# 2395                         0   Personal Auto   Two-Door Car
# 436                     1/0/00   Personal Auto   Two-Door Car
# 957                     1/1/00   Personal Auto  Four-Door Car
# 3203                         1   Personal Auto  Four-Door Car
#
#       total_claim_amount
# 2888          165.570243
# 741           165.570243
# 1706          345.600000
# 3592          345.600000
# 416           101.288069
# 2086          101.288069
# 2442          188.938397
# 884           188.938397
# 1373          316.227946
# 3400          316.227946
# 594           136.291083
# 2663          136.291083
# 2158          114.798771
# 440           114.798771
# 2675          278.999409
# 1187          278.999409
# 178            68.179721
# 3548           68.179721
# 3377          125.933005
# 546           125.933005
# 3090          379.029102
# 2046          379.029102
# 354            91.146661
# 3533           91.146661
# 3066          255.005116
# 1091          255.005116
# 1072          547.200000
# 1069          547.200000
# 2973          321.600000
# 1444          321.600000
# 661           156.124914
# 2244          156.124914
# 1499          321.600000
# 2772          321.600000
# 3421           49.451117
# 120            49.451117
# 933           213.225001
# 3803          213.225001
# 4              17.269323
# 3937           17.269323
# 1323          305.121363
# 2496          305.121363
# 1471          321.600000
# 3113          321.600000
# 3736           46.158117
# 111            46.158117
# 1068          633.600000
# 1071          633.600000
# 176            61.693771
# 3253           61.693771
# 1947          355.200000
# 2917          355.200000
# 2741          163.046956
# 731           163.046956
# 3042           20.985105
# 27             20.985105
# 2395          114.273025
# 436           114.273025
# 957           220.186677
# 3203          220.186677

# %%
compare_duplicates()
# Out:
# No duplicates

# %% [markdown]
# ## Analyse duplicates
# - customer duplicates are almost the same
# - second duplicate is cleaner than the first.
# - keep second
# - How to correct "Number of open complaints":
#     - 1/0/00 => 0
#     - 1/1/00 => 1
#     - 1/3/00 => 3
#     - etc.

# %%
## Show how many NAN in column customer:
df[df["customer"].isna()== True]
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
## As there are  no nan-values we can
## Drop customer duplicates and keep last:
df = df.drop_duplicates(subset = "customer", keep="last")
df.customer.describe()
# Out:
# count        9056
# unique       9056
# top       RB50392
# freq            1
# Name: customer, dtype: object

# %%
## we get rid of column "customer"
#df["columns"] = 
df = df.drop("customer", axis=1)
df.head(1)
# Out:
#         state gender education  customer_lifetime_value  income  \
# 0  Washington    NaN    Master                      NaN     0.0
#
#    monthly_premium_auto number_of_open_complaints    policy_type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934

# %% [markdown]
# ## Clean number of open complaints

# %%
# check count of unique values
df.number_of_open_complaints.value_counts()
# Out:
# 0         5629
# 1/0/00    1561
# 1          765
# 2          283
# 1/1/00     236
# 3          230
# 4          119
# 1/2/00      91
# 1/3/00      58
# 5           44
# 1/4/00      29
# 1/5/00      11
# Name: number_of_open_complaints, dtype: int64

# %%
## replace value with value in positon 2 of str modified to int
df.loc[:,"number_of_open_complaints"] = list(map(lambda x: int(x[2]) if (type(x) == str and len(x)>2) else x, df.loc[:,"number_of_open_complaints"]))

# %%
# check values after function
df.number_of_open_complaints.value_counts()
# Out:
# 0    7190
# 1    1001
# 2     374
# 3     288
# 4     148
# 5      55
# Name: number_of_open_complaints, dtype: int64

# %% [markdown]
# ## Correcting typos on column gender and state

# %%
round(df.isna().sum()/len(df),4)*100
# Out:
# customer                     0.00
# state                        0.00
# gender                       1.34
# education                    0.00
# customer_lifetime_value      0.08
# income                       0.00
# monthly_premium_auto         0.00
# number_of_open_complaints    0.00
# policy_type                  0.00
# vehicle_class                0.00
# total_claim_amount           0.00
# dtype: float64
