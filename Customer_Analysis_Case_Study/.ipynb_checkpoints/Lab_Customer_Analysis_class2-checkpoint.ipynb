# %% [markdown]
# # Lab Customer Analysis Case Study
#
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Load files and store data in variable
#
# ### Have a look at the data to get an overview

# %%
# load data and store in variable
file1 = pd.read_csv("Data/Data_Marketing_Customer_Analysis_Round2.csv", index_col=False)
#file2 = pd.read_csv("Data/file2.csv")
#file3 = pd.read_csv("Data/file3.csv")
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %% [markdown]
# ## Define functions to clean column labels before concating
#  - all lower case
#  - replace space with underscore

# %%
# create functions to rename and sort columns
# make columns lower case
def make_columns_lower_case(df):
    #df.columns=[i.lower() for i in df.columns]
    df.columns = df.columns.str.lower()
    return df

# replace space " " with underscore "_"
def replace_space(df):
    df.columns=[i.replace(" ","_") for i in df.columns]
    return df

# lower and replace space
def columns_lower_no_space(df):
    """ 
    Info: Columns of DataFrame will be manipulated: 
            1. All letters will be lowered.
            2. Spaces " " will be replaced with underscores "_"
    """
    make_columns_lower_case(df)
    replace_space(df)
    return df

# %% [markdown]
# ### Apply function on loaded files
# ### Have a look at the column labels

# %%
# modify column: lower letters and replace space and delete index column
file1 = columns_lower_no_space(file1).drop(columns={"unnamed:_0"})
# file2 = columns_lower_no_space(file2)
# file3 = columns_lower_no_space(file3)

# compare the columns
pd.DataFrame([file1.columns])
# Out:
#          0      1                        2         3         4          5   \
# 0  customer  state  customer_lifetime_value  response  coverage  education
#
#                   6                 7       8       9   ...  \
# 0  effective_to_date  employmentstatus  gender  income  ...
#
#                           15                  16           17      18  \
# 0  number_of_open_complaints  number_of_policies  policy_type  policy
#
#                  19             20                  21             22  \
# 0  renew_offer_type  sales_channel  total_claim_amount  vehicle_class
#
#              23            24
# 0  vehicle_size  vehicle_type
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Concat data to one dataframe
# ### show info

# %%
df = pd.concat([file1],ignore_index = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
#  12  monthly_premium_auto           10910 non-null  int64
#  13  months_since_last_claim        10277 non-null  float64
#  14  months_since_policy_inception  10910 non-null  int64
#  15  number_of_open_complaints      10277 non-null  float64
#  16  number_of_policies             10910 non-null  int64
#  17  policy_type                    10910 non-null  object
#  18  policy                         10910 non-null  object
#  19  renew_offer_type               10910 non-null  object
#  20  sales_channel                  10910 non-null  object
#  21  total_claim_amount             10910 non-null  float64
#  22  vehicle_class                  10288 non-null  object
#  23  vehicle_size                   10288 non-null  object
#  24  vehicle_type                   5428 non-null   object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Calculate percentage of NaN values and zero values in columns
#
# ## ToDo: add columns for: type, No of categories, range, count, unique

# %%
# calculate percentage of NaN values and zero values in columns
pd.DataFrame({"% NaN" : round(df.isna().sum()/len(df),4)*100, "% 0.0" : round(df[df == 0].count(axis=0)/len(df.index)* 100,2)})
# Out:
#                                % NaN  % 0.0
# customer                        0.00   0.00
# state                           5.78   0.00
# customer_lifetime_value         0.00   0.00
# response                        5.78   0.00
# coverage                        0.00   0.00
# education                       0.00   0.00
# effective_to_date               0.00   0.00
# employmentstatus                0.00   0.00
# gender                          0.00   0.00
# income                          0.00  25.55
# location_code                   0.00   0.00
# marital_status                  0.00   0.00
# monthly_premium_auto            0.00   0.00
# months_since_last_claim         5.80   3.24
# months_since_policy_inception   0.00   0.98
# number_of_open_complaints       5.80  74.79
# number_of_policies              0.00   0.00
# policy_type                     0.00   0.00
# policy                          0.00   0.00
# renew_offer_type                0.00   0.00
# sales_channel                   0.00   0.00
# total_claim_amount              0.00   0.00
# vehicle_class                   5.70   0.00
# vehicle_size                    5.70   0.00
# vehicle_type                   50.25   0.00

# %% [markdown]
# ## Start cleaning Data - start with "nobrainers"
# ### Drop empty lines (all nan)
# ### Drop unnessesary columns
#
# ### ToDo: add a function to drop lines with more than % empty

# %%
df = df.dropna(how="all")
df = df.reset_index().drop(columns={"index"})
df
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# 0       College           2/18/11         Employed      M   48029  ...
# 1       College           1/18/11       Unemployed      F       0  ...
# 2      Bachelor           2/10/11         Employed      M   22139  ...
# 3       College           1/11/11         Employed      M   49078  ...
# 4      Bachelor           1/17/11    Medical Leave      F   23675  ...
# ...         ...               ...              ...    ...     ...  ...
# 10905  Bachelor           1/19/11       Unemployed      F       0  ...
# 10906   College            1/6/11         Employed      F   61146  ...
# 10907  Bachelor            2/6/11         Employed      F   39837  ...
# 10908   College           2/13/11         Employed      F   64195  ...
# 10909  Bachelor            1/8/11       Unemployed      M       0  ...
#
#       number_of_open_complaints number_of_policies     policy_type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %% [markdown]
# ## Clean data of individual columns
# ### Clean custome lifetime value:
# - create function
#     - identify "%".
#     - strip %
#     - make float/numeric
#     - divide by 100
# - imply function on column customer_lifetime_value

# %%
# create function to identify and strip %. turn to float/numeric and divide by 100
def clean_percentage(number):
    if type(number) in [float,int]:
        return number
    else:
        if "%" in number:
            return pd.to_numeric(number.rstrip("%"))/100
        else: 
            try:
                return pd.to_numeric(number)
            except ValueError:
                return number

# test function
# list(map(clean_percentage,[100,200.0,"300","400%","sdf"]))

# %%
## apply clean_percentage on customer_lifetime_value

df["customer_lifetime_value"] = list(map(clean_percentage, df["customer_lifetime_value"]))

# %% [markdown]
# ### Clean data of column customer
# #### Have a look at customer values
# - show count and unique
# - show duplicates

# %%
df.customer.describe()
# Out:
# count       10910
# unique       9134
# top       ID89933
# freq            7
# Name: customer, dtype: object

# %% [markdown]
# ### Create function to show duplicates
#
# ### ToDo: apply 2nd sort: index

# %%
def compare_duplicates( df = df, column = None  , amount = 10):
    ''' 
    compare_duplicates( DataFrame = df, column = none, amount = 10)
    
    column:     column to check for duplicated, if None > check all columns
    amount:     show first first amount of rows
    '''

    try:
        return df.loc[df.duplicated(subset=column, keep=False)].sort_values(by=column).head(amount)
    except KeyError:
        print("No duplicates")

# %% [markdown]
# ### Compare duplicates in column customer
# - same data?
# - which one to keep? (last,first,none,all?)
# - compare values in other columns to see inconsequent values or value pattern

# %%
compare_duplicates(df, "customer", 10)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 8731   AA10041  California              7901.744238       No     Basic
# 10376  AA10041  California              7901.744238       No     Basic
# 3960   AA10041         NaN              7901.744238      NaN     Basic
# 432    AA11235      Nevada              2568.843396       No     Basic
# 6044   AA11235      Nevada              2568.843396       No     Basic
# 5078   AA56476     Arizona              5595.389905      Yes     Basic
# 10422  AA56476     Arizona              5595.389905      Yes     Basic
# 4601   AA71604     Arizona             11986.592120       No  Extended
# 5435   AA71604     Arizona             11986.592120       No  Extended
# 6360   AB21519  California              3861.486269      Yes  Extended
#
#                   education effective_to_date employmentstatus gender  income  \
# 8731   High School or Below            2/2/11       Unemployed      M       0
# 10376  High School or Below            2/2/11       Unemployed      M       0
# 3960   High School or Below            2/2/11       Unemployed      M       0
# 432                Bachelor           1/28/11    Medical Leave      F   11167
# 6044               Bachelor           1/28/11    Medical Leave      F   11167
# 5078   High School or Below            2/5/11         Employed      F   74454
# 10422  High School or Below            2/5/11         Employed      F   74454
# 4601                 Master           1/17/11         Employed      F   87560
# 5435                 Master           1/17/11         Employed      F   87560
# 6360                College            1/6/11         Employed      F   93272
#
#        ... number_of_open_complaints number_of_policies     policy_type  \
# 8731   ...                       0.0                  5   Personal Auto
# 10376  ...                       0.0                  5   Personal Auto
# 3960   ...                       0.0                  5   Personal Auto
# 432    ...                       NaN                  1   Personal Auto
# 6044   ...                       3.0                  1   Personal Auto
# 5078   ...                       0.0                  3  Corporate Auto
# 10422  ...                       NaN                  3  Corporate Auto
# 4601   ...                       1.0                  2   Personal Auto
# 5435   ...                       1.0                  2   Personal Auto
# 6360   ...                       0.0                  1   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 8731    Personal L3            Offer1    Call Center         1258.327804
# 10376   Personal L3            Offer1    Call Center         1258.327804
# 3960    Personal L3            Offer1    Call Center         1258.327804
# 432     Personal L3            Offer2         Branch          350.400000
# 6044    Personal L3            Offer2         Branch          350.400000
# 5078   Corporate L2            Offer2    Call Center          340.800000
# 10422  Corporate L2            Offer2    Call Center          340.800000
# 4601    Personal L2            Offer1            Web          470.400000
# 5435    Personal L2            Offer1            Web          470.400000
# 6360    Personal L3            Offer2         Branch          281.110788
#
#        vehicle_class vehicle_size vehicle_type
# 8731             SUV      Medsize            A
# 10376            NaN          NaN            A
# 3960             SUV      Medsize            A
# 432     Two-Door Car      Medsize          NaN
# 6044    Two-Door Car      Medsize            A
# 5078   Four-Door Car      Medsize            A
# 10422  Four-Door Car      Medsize          NaN
# 4601             NaN          NaN            A
# 5435    Two-Door Car      Medsize          NaN
# 6360   Four-Door Car      Medsize          NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Analyse duplicates
# - customer duplicates are almost the same
# - second duplicate is cleaner than the first.
# - keep second
# - How to correct "Number of open complaints":
#     - 1/0/00 => 0
#     - 1/1/00 => 1
#     - 1/3/00 => 3
#     - etc.

# %%
## Show how many NAN in column customer:
df[df["customer"].isna()== True]
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### Drop duplicates (based on customer column) and keep last

# %%
## As there are  no nan-values we can
## Drop customer duplicates and keep last:
df = df.drop_duplicates(subset = "customer", keep="last")
df.customer.describe()
# Out:
# count        9134
# unique       9134
# top       KX64629
# freq            1
# Name: customer, dtype: object

# %% [markdown]
# ### Drop column customer

# %%
## we get rid of column "customer"
#df["columns"] = 
df = df.drop(["customer"], axis=1).reset_index(drop=True)
df#.head(1)
# Out:
#            state  customer_lifetime_value response  coverage  \
# 0     California              2228.525238       No     Basic
# 1     Washington             14947.917300       No     Basic
# 2         Oregon             22332.439460      Yes  Extended
# 3     California              5035.035257       No     Basic
# 4     California              4956.247235       No     Basic
# ...          ...                      ...      ...       ...
# 9129      Nevada             15563.369440       No   Premium
# 9130      Oregon              5259.444853       No     Basic
# 9131     Arizona             23893.304100       No  Extended
# 9132  California             11971.977650       No   Premium
# 9133         NaN              6857.519928      NaN     Basic
#
#                  education effective_to_date employmentstatus gender  income  \
# 0                  College           1/18/11       Unemployed      F       0
# 1                 Bachelor           2/10/11         Employed      M   22139
# 2                  College           1/11/11         Employed      M   49078
# 3                   Doctor           2/14/11         Employed      F   37405
# 4     High School or Below           2/24/11         Employed      M   87197
# ...                    ...               ...              ...    ...     ...
# 9129              Bachelor           1/19/11       Unemployed      F       0
# 9130               College            1/6/11         Employed      F   61146
# 9131              Bachelor            2/6/11         Employed      F   39837
# 9132               College           2/13/11         Employed      F   64195
# 9133              Bachelor            1/8/11       Unemployed      M       0
#
#      location_code  ... number_of_open_complaints  number_of_policies  \
# 0         Suburban  ...                       0.0                   1
# 1         Suburban  ...                       0.0                   2
# 2         Suburban  ...                       0.0                   2
# 3            Urban  ...                       3.0                   4
# 4            Urban  ...                       0.0                   3
# ...            ...  ...                       ...                 ...
# 9129      Suburban  ...                       NaN                   7
# 9130         Urban  ...                       0.0                   6
# 9131         Rural  ...                       0.0                   2
# 9132         Urban  ...                       4.0                   6
# 9133      Suburban  ...                       0.0                   3
#
#          policy_type        policy  renew_offer_type  sales_channel  \
# 0      Personal Auto   Personal L3            Offer4    Call Center
# 1      Personal Auto   Personal L3            Offer3    Call Center
# 2     Corporate Auto  Corporate L3            Offer2         Branch
# 3     Corporate Auto  Corporate L2            Offer2         Branch
# 4      Personal Auto   Personal L2            Offer2         Branch
# ...              ...           ...               ...            ...
# 9129   Personal Auto   Personal L1            Offer3            Web
# 9130   Personal Auto   Personal L3            Offer2         Branch
# 9131  Corporate Auto  Corporate L3            Offer1            Web
# 9132   Personal Auto   Personal L1            Offer1         Branch
# 9133   Personal Auto   Personal L1            Offer4            Web
#
#      total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0            744.924331  Four-Door Car      Medsize          NaN
# 1            480.000000            SUV      Medsize            A
# 2            484.013411  Four-Door Car      Medsize            A
# 3            287.556107  Four-Door Car      Medsize          NaN
# 4            247.402353   Two-Door Car      Medsize          NaN
# ...                 ...            ...          ...          ...
# 9129        1214.400000     Luxury Car      Medsize            A
# 9130         273.018929  Four-Door Car      Medsize            A
# 9131         381.306996     Luxury SUV      Medsize          NaN
# 9132         618.288849            SUV      Medsize            A
# 9133        1021.719397            SUV      Medsize          NaN
#
# [9134 rows x 24 columns]

# %% [markdown]
# ## Clean number of open complaints
# ### check count of unique values

# %%
# check count of unique values
df.number_of_open_complaints.value_counts()
# Out:
# 0.0    7026
# 1.0     981
# 2.0     366
# 3.0     281
# 4.0     144
# 5.0      53
# Name: number_of_open_complaints, dtype: int64

# %%
## replace value with value in positon 2 of str modified to int
df.loc[:,"number_of_open_complaints"] = list(map(lambda x: int(x[2]) if (type(x) == str and len(x)>2) else x, df.loc[:,"number_of_open_complaints"]))

# %%
# check values after function
df.number_of_open_complaints.value_counts()
# Out:
# 0.0    7026
# 1.0     981
# 2.0     366
# 3.0     281
# 4.0     144
# 5.0      53
# Name: number_of_open_complaints, dtype: int64

# %% [markdown]
# ## Filtering data and Correcting typos
# ### Filter the data in state and gender column to standardize the texts in those columns
#
# #### Clean Gender Column

# %%
df.gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
# check gender values
df.gender.value_counts()
# Out:
# F    4658
# M    4476
# Name: gender, dtype: int64

# %% [markdown]
# ### Function to rename gender names
#
# ### ToDo: put function in "basic"-rename function with predefined dic or like following

# %%
# def function to rename values

def rename_gender_values(x):
    if type(x) == str:
        if x[0] in ["F","f"]:
            return "F"
        elif x[0] in ["m","M"]:
            return "M"
        else:
            return "U"
    else:
        return "U"
# Test function
#list(map(rename_gender_values, ["F","femle","mal","M",1,"sokl"]))

# %%
df.gender = df.gender.apply(rename_gender_values)
df.gender.value_counts()
# Out:
# F    4658
# M    4476
# Name: gender, dtype: int64

# %% [markdown]
# ### Clean state column

# %%
## check state values
df.state.unique()
# Out:
# array(['California', 'Washington', 'Oregon', 'Arizona', 'Nevada', nan],
#       dtype=object)

# %%
df.state.value_counts()
# Out:
# California    3059
# Oregon        2524
# Arizona       1656
# Nevada         857
# Washington     775
# Name: state, dtype: int64

# %%
# def function to rename values
def rename_state_values( x , dict ):
    """ 
    rename_state_values( x , dict ):
        x:  argument to test/rename
        dict: argument to compared to
            - keys of dict are valiable values
            - values of dict are likely missspelled strings
    Example:
        replace_state_dic = {'Washington' : ['WA'], 'Arizona' : ['AZ','Ariznoa']}
        list(map(lambda x: rename_state_values(x,replace_state_dic), ["WA","Arizona","AZ","Arinoa"]))

        Output:
        ['Washington', 'Arizona', 'Arizona', None]

    Example to use on df:
    replace_state_dic = {'Washington' : ['WA',"W"], 'Arizona' : ["AZ","Ari"] , 'Nevada' : [] , 'California': ["cali","CA","Cali"] , 'Oregon' : []}
    df.state = list(map(lambda x: rename_state_values(x,replace_state_dic), df.state))

    Value_counts:
    before: California    3030
            Oregon        2601
            Arizona       1629
            Nevada         882
            Washington     690
            Cali           120
            AZ              74
            WA              30

    after:  California    3150
            Oregon        2601
            Arizona       1703
            Nevada         882
            Washington     720
    """
    if x in dict.keys():
        return x
    for key, list_substitutes in dict.items():
        if x in list_substitutes:
            return key
    return

# %%
# Test function
#list(map(lambda x: rename_state_values(x,replace_state_dic), ["Cali","WA","Arizona","California","Cali","AZ","W","Ari","AZ","Cali",1,"sokl","Cali"]))

# %%
# create Dic with valiable values for state as keys and and likely missspelled values as a list of values
replace_state_dic = {'Washington' : ['WA',"W"], 'Arizona' : ["AZ","Ari"] , 'Nevada' : [] , 'California': ["cali","CA","Cali"] , 'Oregon' : []}

# use rename funcion on df.state
df.state = list(map(lambda x: rename_state_values(x,replace_state_dic), df.state))
df.state.value_counts()
# Out:
# California    3059
# Oregon        2524
# Arizona       1656
# Nevada         857
# Washington     775
# Name: state, dtype: int64

# %% [markdown]
# ## Replacing null values
# ### Replace missing values with means of the column (for numerical columns)
#
# ### Overview of Nullvalues and NaN:

# %%
# calculate percentage of NaN values and zero values in columns
pd.DataFrame({"% NaN" : round(df.isna().sum()/len(df),4)*100, "% 0.0" : round(df[df == 0].count(axis=0)/len(df.index)* 100,2)})
# Out:
#                                % NaN  % 0.0
# state                           2.88   0.00
# customer_lifetime_value         0.00   0.00
# response                        2.88   0.00
# coverage                        0.00   0.00
# education                       0.00   0.00
# effective_to_date               0.00   0.00
# employmentstatus                0.00   0.00
# gender                          0.00   0.00
# income                          0.00  25.37
# location_code                   0.00   0.00
# marital_status                  0.00   0.00
# monthly_premium_auto            0.00   0.00
# months_since_last_claim         3.10   3.37
# months_since_policy_inception   0.00   0.91
# number_of_open_complaints       3.10  76.92
# number_of_policies              0.00   0.00
# policy_type                     0.00   0.00
# policy                          0.00   0.00
# renew_offer_type                0.00   0.00
# sales_channel                   0.00   0.00
# total_claim_amount              0.00   0.00
# vehicle_class                   2.93   0.00
# vehicle_size                    2.93   0.00
# vehicle_type                   50.16   0.00

# %% [markdown]
# ### Eliminate 0-values in income with calculated mean

# %%
# have a look at income values
df.income.value_counts()
#df.income
# Out:
# 0        2317
# 95697      12
# 27972       7
# 26876       7
# 24910       7
#          ...
# 23811       1
# 35289       1
# 54780       1
# 93246       1
# 64195       1
# Name: income, Length: 5694, dtype: int64

# %% [markdown]
# ### Calculate mean of income but ignore 0
# ### ToDO: use variable instead of manually put in 0-count

# %%
# calculate mean of income without zero
mean_income_no_zero = df.income.sum()/(len(df.income)-2317) # entered count of zeros manually
mean_income_no_zero
# Out:
# 50456.58046061317

# %%
# mean with zeros for comparison
df.income.mean()
# Out:
# 37657.38000875848

# %%
# replace 0.0-values with mean_income_no_zero
df.income = list(map(lambda x: mean_income_no_zero if x == 0.0 else x, df.income))

# %% [markdown]
# ### Replace NaN values in column customer_lifetime_value
#
# ### ToDo: check if mean() and mean without NaN is the same

# %%
df.customer_lifetime_value.isna().sum()
# Out:
# 0

# %%
# have a look at customer_lifetime_value values
# df.customer_lifetime_value.value_counts()
#df.isna().sum().loc["customer_lifetime_value"]
df.customer_lifetime_value
# Out:
# 0        2228.525238
# 1       14947.917300
# 2       22332.439460
# 3        5035.035257
# 4        4956.247235
#             ...
# 9129    15563.369440
# 9130     5259.444853
# 9131    23893.304100
# 9132    11971.977650
# 9133     6857.519928
# Name: customer_lifetime_value, Length: 9134, dtype: float64

# %%
# calculate mean of "customer_lifetime_value" without zero
mean_customer_lifetime_value_no_zero = (df
                                                .customer_lifetime_value
                                                .sum()
                                            /(len(df.
                                                    customer_lifetime_value)
                                        -(df
                                            .isna()
                                            .sum()
                                            .loc["customer_lifetime_value"])))
mean_customer_lifetime_value_no_zero
# Out:
# 8004.940474987081

# %%
df.customer_lifetime_value.mean()
# Out:
# 8004.940474987084

# %%
df.customer_lifetime_value = df.customer_lifetime_value.fillna(mean_customer_lifetime_value_no_zero) # check if mean by function is same as manually calculated for poplation incl. NaN

# %%
# have a look at customer_lifetime_value values
# df.customer_lifetime_value.value_counts()
#df.isna().sum().loc["customer_lifetime_value"]
df.customer_lifetime_value
# Out:
# 0        2228.525238
# 1       14947.917300
# 2       22332.439460
# 3        5035.035257
# 4        4956.247235
#             ...
# 9129    15563.369440
# 9130     5259.444853
# 9131    23893.304100
# 9132    11971.977650
# 9133     6857.519928
# Name: customer_lifetime_value, Length: 9134, dtype: float64

# %% [markdown]
# # Activity 2
#
# ## Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
#
# ### create function to rename values. Use dataframe as input and a dict as a renaming advice

# %%
# def function to rename values
def rename_values( x , dict ):
    """ 
    rename_values( x , dict ):
        x:  argument to test/rename
        dict: argument to compared to
            - keys of dict are valiable values
            - values of dict are likely missspelled strings
    Example:
        replace_state_dic = {'Washington' : ['WA'], 'Arizona' : ['AZ','Ariznoa']}
        list(map(lambda x: rename_state_values(x,replace_state_dic), ["WA","Arizona","AZ","Arinoa"]))

        Output:
        ['Washington', 'Arizona', 'Arizona', None]

    Example to use on df:
    replace_state_dic = {'Washington' : ['WA',"W"], 'Arizona' : ["AZ","Ari"] , 'Nevada' : [] , 'California': ["cali","CA","Cali"] , 'Oregon' : []}
    df.state = list(map(lambda x: rename_state_values(x,replace_state_dic), df.state))

    Value_counts:
    before: California    3030
            Oregon        2601
            Arizona       1629
            Nevada         882
            Washington     690
            Cali           120
            AZ              74
            WA              30

    after:  California    3150
            Oregon        2601
            Arizona       1703
            Nevada         882
            Washington     720
    """
    if x in dict.keys():
        return x
    for key, list_substitutes in dict.items():
        if x in list_substitutes:
            return key
    return

# %%
# Test function
#list(map(lambda x: rename_state_values(x,replace_state_dic), ["Cali","WA","Arizona","California","Cali","AZ","W","Ari","AZ","Cali",1,"sokl","Cali"]))

# %%
# create Dic with valiable values for state as keys and and likely missspelled values as a list of values
replace_state_region_dic = {'West Region' : ["California"], 'North West' : ["Oregon"] , 'East' : ["Washington"] , 'Central': ["Nevada","Arizona"] }

# use rename funcion on df.state
df["region"] = list(map(lambda x: rename_values(x,replace_state_region_dic), df.state))
# df.region.value_counts()
df
# Out:
#            state  customer_lifetime_value response  coverage  \
# 0     California              2228.525238       No     Basic
# 1     Washington             14947.917300       No     Basic
# 2         Oregon             22332.439460      Yes  Extended
# 3     California              5035.035257       No     Basic
# 4     California              4956.247235       No     Basic
# ...          ...                      ...      ...       ...
# 9129      Nevada             15563.369440       No   Premium
# 9130      Oregon              5259.444853       No     Basic
# 9131     Arizona             23893.304100       No  Extended
# 9132  California             11971.977650       No   Premium
# 9133        None              6857.519928      NaN     Basic
#
#                  education effective_to_date employmentstatus gender  \
# 0                  College           1/18/11       Unemployed      F
# 1                 Bachelor           2/10/11         Employed      M
# 2                  College           1/11/11         Employed      M
# 3                   Doctor           2/14/11         Employed      F
# 4     High School or Below           2/24/11         Employed      M
# ...                    ...               ...              ...    ...
# 9129              Bachelor           1/19/11       Unemployed      F
# 9130               College            1/6/11         Employed      F
# 9131              Bachelor            2/6/11         Employed      F
# 9132               College           2/13/11         Employed      F
# 9133              Bachelor            1/8/11       Unemployed      M
#
#             income location_code  ... number_of_policies     policy_type  \
# 0     50456.580461      Suburban  ...                  1   Personal Auto
# 1     22139.000000      Suburban  ...                  2   Personal Auto
# 2     49078.000000      Suburban  ...                  2  Corporate Auto
# 3     37405.000000         Urban  ...                  4  Corporate Auto
# 4     87197.000000         Urban  ...                  3   Personal Auto
# ...            ...           ...  ...                ...             ...
# 9129  50456.580461      Suburban  ...                  7   Personal Auto
# 9130  61146.000000         Urban  ...                  6   Personal Auto
# 9131  39837.000000         Rural  ...                  2  Corporate Auto
# 9132  64195.000000         Urban  ...                  6   Personal Auto
# 9133  50456.580461      Suburban  ...                  3   Personal Auto
#
#             policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Personal L3            Offer4    Call Center          744.924331
# 1      Personal L3            Offer3    Call Center          480.000000
# 2     Corporate L3            Offer2         Branch          484.013411
# 3     Corporate L2            Offer2         Branch          287.556107
# 4      Personal L2            Offer2         Branch          247.402353
# ...            ...               ...            ...                 ...
# 9129   Personal L1            Offer3            Web         1214.400000
# 9130   Personal L3            Offer2         Branch          273.018929
# 9131  Corporate L3            Offer1            Web          381.306996
# 9132   Personal L1            Offer1         Branch          618.288849
# 9133   Personal L1            Offer4            Web         1021.719397
#
#       vehicle_class vehicle_size vehicle_type       region
# 0     Four-Door Car      Medsize          NaN  West Region
# 1               SUV      Medsize            A         East
# 2     Four-Door Car      Medsize            A   North West
# 3     Four-Door Car      Medsize          NaN  West Region
# 4      Two-Door Car      Medsize          NaN  West Region
# ...             ...          ...          ...          ...
# 9129     Luxury Car      Medsize            A      Central
# 9130  Four-Door Car      Medsize            A   North West
# 9131     Luxury SUV      Medsize          NaN      Central
# 9132            SUV      Medsize            A  West Region
# 9133            SUV      Medsize          NaN         None
#
# [9134 rows x 25 columns]

# %% [markdown]
# ## Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
## checking values of policy type
df.policy_type.value_counts()

### Data looks clean only need for lower case
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
# make all string lower case
df = df.applymap(lambda x: x if type(x)!=str else x.lower())

# %%
#list(df.columns)

# %%
##which columns are numeric/object?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          8871 non-null   object
#  1   customer_lifetime_value        9134 non-null   float64
#  2   response                       8871 non-null   object
#  3   coverage                       9134 non-null   object
#  4   education                      9134 non-null   object
#  5   effective_to_date              9134 non-null   object
#  6   employmentstatus               9134 non-null   object
#  7   gender                         9134 non-null   object
#  8   income                         9134 non-null   float64
#  9   location_code                  9134 non-null   object
#  10  marital_status                 9134 non-null   object
#  11  monthly_premium_auto           9134 non-null   int64
#  12  months_since_last_claim        8851 non-null   float64
#  13  months_since_policy_inception  9134 non-null   int64
#  14  number_of_open_complaints      8851 non-null   float64
#  15  number_of_policies             9134 non-null   int64
#  16  policy_type                    9134 non-null   object
#  17  policy                         9134 non-null   object
#  18  renew_offer_type               9134 non-null   object
#  19  sales_channel                  9134 non-null   object
#  20  total_claim_amount             9134 non-null   float64
#  21  vehicle_class                  8866 non-null   object
#  22  vehicle_size                   8866 non-null   object
#  23  vehicle_type                   4552 non-null   object
#  24  region                         8871 non-null   object
# dtypes: float64(5), int64(3), object(17)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Table with numeric data

# %%
df._get_numeric_data()
# Out:
#       customer_lifetime_value        income  monthly_premium_auto  \
# 0                 2228.525238  50456.580461                    64
# 1                14947.917300  22139.000000                   100
# 2                22332.439460  49078.000000                    97
# 3                 5035.035257  37405.000000                    63
# 4                 4956.247235  87197.000000                    63
# ...                       ...           ...                   ...
# 9129             15563.369440  50456.580461                   253
# 9130              5259.444853  61146.000000                    65
# 9131             23893.304100  39837.000000                   201
# 9132             11971.977650  64195.000000                   158
# 9133              6857.519928  50456.580461                   101
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                         3.0                             26
# 1                        34.0                             31
# 2                        10.0                              3
# 3                         8.0                             99
# 4                        35.0                             45
# ...                       ...                            ...
# 9129                      NaN                             40
# 9130                      7.0                             68
# 9131                     11.0                             63
# 9132                      0.0                             27
# 9133                     31.0                              1
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                           0.0                   1          744.924331
# 1                           0.0                   2          480.000000
# 2                           0.0                   2          484.013411
# 3                           3.0                   4          287.556107
# 4                           0.0                   3          247.402353
# ...                         ...                 ...                 ...
# 9129                        NaN                   7         1214.400000
# 9130                        0.0                   6          273.018929
# 9131                        0.0                   2          381.306996
# 9132                        4.0                   6          618.288849
# 9133                        0.0                   3         1021.719397
#
# [9134 rows x 8 columns]

# %% [markdown]
# ### Activity 4

# %% [markdown]
# - Show a plot of the total number of responses.

# %%
number_responses = df.response.value_counts()
number_responses
# Out:
# no     7595
# yes    1276
# Name: response, dtype: int64

# %%
# Create bars
fig, ax = plt.subplots(1,1,figsize=(6,6))
ax.bar(number_responses.index, number_responses, color=("red","green"))
ax.set_title("Total number of responses",{"fontsize":20})
#ax.xaxis.set(ticks=[0,1], ticklabels=["died","survived"])
#ax.tick_params(axis='y', direction = "inout",length=10)
# Out:
# Text(0.5, 1.0, 'Total number of responses')

# %% [markdown]
# - Show a plot of the response rate by the sales channel.

# %%
df.response.value_counts(normalize=True)
# Out:
# no     0.856161
# yes    0.143839
# Name: response, dtype: float64

# %%
response_rate = df.groupby(["sales_channel","response"])["response"].count().rename("count")
res_rate_by_channel = response_rate / response_rate.groupby(level=0).sum() * 100
res_rate_by_channel
# Out:
# sales_channel  response
# agent          no          80.857988
#                yes         19.142012
# branch         no          88.432389
#                yes         11.567611
# call center    no          89.077103
#                yes         10.922897
# web            no          88.050314
#                yes         11.949686
# Name: count, dtype: float64

# %%
channel_response = df.groupby(["sales_channel"])["response"].value_counts(normalize=True)
df_channel_response = pd.DataFrame({"channel_response_rate":channel_response}).reset_index()
df_channel_response
# Out:
#   sales_channel response  channel_response_rate
# 0         agent       no               0.808580
# 1         agent      yes               0.191420
# 2        branch       no               0.884324
# 3        branch      yes               0.115676
# 4   call center       no               0.890771
# 5   call center      yes               0.109229
# 6           web       no               0.880503
# 7           web      yes               0.119497

# %%
sns.set_palette("RdYlGn")
fig.ax = plt.subplots(figsize = (6,6))
sns.barplot(x="sales_channel", y="channel_response_rate", data=df_channel_response, hue="response")#, hue = response_rate["response"])
ax.set_title("Response rate by sales channel")
plt.show()

# %% [markdown]
# - Show a plot of the response rate by the total claim amount.

# %%
## create buckets for total claim amount
df.total_claim_amount.describe()
# Out:
# count    9134.000000
# mean      434.088794
# std       290.500092
# min         0.099007
# 25%       272.258244
# 50%       383.945434
# 75%       547.514839
# max      2893.239678
# Name: total_claim_amount, dtype: float64

# %%
# Check bin range and count of binned values
df.total_claim_amount.value_counts(sort = False, bins = 20)
# Out:
# (-2.795, 144.756]       1279
# (144.756, 289.413]      1171
# (289.413, 434.07]       2764
# (434.07, 578.727]       1971
# (578.727, 723.384]       845
# (723.384, 868.041]       457
# (868.041, 1012.698]      265
# (1012.698, 1157.355]     121
# (1157.355, 1302.012]     101
# (1302.012, 1446.669]      82
# (1446.669, 1591.326]      25
# (1591.326, 1735.983]      11
# (1735.983, 1880.64]       12
# (1880.64, 2025.297]       11
# (2025.297, 2169.955]       8
# (2169.955, 2314.612]       5
# (2314.612, 2459.269]       3
# (2459.269, 2603.926]       1
# (2603.926, 2748.583]       0
# (2748.583, 2893.24]        2
# Name: total_claim_amount, dtype: int64

# %%
## asign binned values of total claim amount to a new column
df['total_claim_amount_binned'] = pd.cut(df['total_claim_amount'],20)
df.total_claim_amount_binned.to_frame()
# Out:
#      total_claim_amount_binned
# 0           (723.384, 868.041]
# 1            (434.07, 578.727]
# 2            (434.07, 578.727]
# 3           (144.756, 289.413]
# 4           (144.756, 289.413]
# ...                        ...
# 9129      (1157.355, 1302.012]
# 9130        (144.756, 289.413]
# 9131         (289.413, 434.07]
# 9132        (578.727, 723.384]
# 9133      (1012.698, 1157.355]
#
# [9134 rows x 1 columns]

# %%
claim_response = df.groupby(["total_claim_amount_binned","response"])["response"].count().rename("total_claim_amount")
claim_response = claim_response / claim_response.groupby(level=0).sum() #*100 if answer should be in percent
claim_response = pd.DataFrame(claim_response).reset_index()
claim_response
# Out:
#    total_claim_amount_binned response  total_claim_amount
# 0          (-2.794, 144.756]       no            0.908797
# 1          (-2.794, 144.756]      yes            0.091203
# 2         (144.756, 289.413]       no            0.894316
# 3         (144.756, 289.413]      yes            0.105684
# 4          (289.413, 434.07]       no            0.830364
# 5          (289.413, 434.07]      yes            0.169636
# 6          (434.07, 578.727]       no            0.817803
# 7          (434.07, 578.727]      yes            0.182197
# 8         (578.727, 723.384]       no            0.848225
# 9         (578.727, 723.384]      yes            0.151775
# 10        (723.384, 868.041]       no            0.919463
# 11        (723.384, 868.041]      yes            0.080537
# 12       (868.041, 1012.698]       no            0.910156
# 13       (868.041, 1012.698]      yes            0.089844
# 14      (1012.698, 1157.355]       no            0.846154
# 15      (1012.698, 1157.355]      yes            0.153846
# 16      (1157.355, 1302.012]       no            0.760000
# 17      (1157.355, 1302.012]      yes            0.240000
# 18      (1302.012, 1446.669]       no            0.848101
# 19      (1302.012, 1446.669]      yes            0.151899
# 20      (1446.669, 1591.326]       no            1.000000
# 21      (1446.669, 1591.326]      yes            0.000000
# 22      (1591.326, 1735.983]       no            1.000000
# 23      (1591.326, 1735.983]      yes            0.000000
# 24       (1735.983, 1880.64]       no            1.000000
# 25       (1735.983, 1880.64]      yes            0.000000
# 26       (1880.64, 2025.297]       no            1.000000
# 27       (1880.64, 2025.297]      yes            0.000000
# 28      (2025.297, 2169.955]       no            1.000000
# 29      (2025.297, 2169.955]      yes            0.000000
# 30      (2169.955, 2314.612]       no            1.000000
# 31      (2169.955, 2314.612]      yes            0.000000
# 32      (2314.612, 2459.269]       no            1.000000
# 33      (2314.612, 2459.269]      yes            0.000000
# 34      (2459.269, 2603.926]       no            1.000000
# 35      (2459.269, 2603.926]      yes            0.000000
# 36      (2603.926, 2748.583]       no                 NaN
# 37      (2603.926, 2748.583]      yes                 NaN
# 38       (2748.583, 2893.24]       no            1.000000
# 39       (2748.583, 2893.24]      yes            0.000000

# %%
sns.set_palette("RdYlGn")
fig.ax = plt.subplots(figsize = (10,10))
sns.barplot(x="total_claim_amount_binned", y="total_claim_amount", data=claim_response, hue="response")
ax.set_title("Response rate by claim_response")
ax.xaxis.set(ticks=[0,500,1000,1500,2000,2500,3000], ticklabels=[0,500,1000,1500,2000,2500,3000])
#ax.tick_params(axis='y', direction = "inout",length=10)
plt.show()

# %% [markdown]
# - Show a plot of the response rate by income.

# %% [markdown]
# - Don't limit your creativity!  plot any interesting findings/insights that describe some interesting facts about your data set and its variables.

# %% [markdown]
# - Plot the Correlation Heatmap.

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Clean your notebook and make it a readible and presentable with a good documentation that summarizes the Data Cleaning, Exploration(including plots) Steps that you have performed.

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)
